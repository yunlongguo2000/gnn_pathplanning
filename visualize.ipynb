# %%
run ./utils/visualize.py --map ./data/Results_best/AnimeDemo/dcpOE/map20x20_rho1_10Agent/K3_HS0/TR_M20p1_10Agent/1582034757/commR_6/input/successCases_ID00000.yaml --schedule  ./data/Results_best/AnimeDemo/dcpOE/map20x20_rho1_10Agent/K3_HS0/TR_M20p1_10Agent/1582034757/commR_6/predict_success/successCases_ID00000.yaml --GSO  ./data/Results_best/AnimeDemo/dcpOE/map20x20_rho1_10Agent/K3_HS0/TR_M20p1_10Agent/1582034757/commR_6/GSO/successCases_ID00000.mat --speed 2 --video ./data/video.mp4 --nGraphFilterTaps 2 --id_chosenAgent 0
